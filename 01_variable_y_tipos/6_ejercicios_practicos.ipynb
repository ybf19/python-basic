# %% [markdown]
# # ✏️ Ejercicios Prácticos - Variables y Tipos de Datos
#
# ## 🎯 Instrucciones
# Resuelve cada ejercicio en las celdas de código debajo de cada enunciado.
#
# ## Ejercicio 1: Presentación personal
# Crea variables para tu nombre, edad, ciudad y profesión.
# Luego imprime una presentación como:
# "Hola, me llamo [nombre], tengo [edad] años, vivo en [ciudad] y soy [profesión]."
